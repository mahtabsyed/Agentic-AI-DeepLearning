# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
# import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-5-nano"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

# def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str:
def generate_draft(topic: str, model: str = "openai:gpt-5-nano") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""For this topic: {topic}, write a detailed draft for a blog post. 
                Make sure to include an introduction, main points, and a conclusion.
                And keep the number of words between 100 and 200 words.
                """
    
    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
# unittests.test_generate_draft(generate_draft)

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-5.2"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

# def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:
def reflect_on_draft(draft: str, model: str = "openai:gpt-5.2") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""Please review the following blog post draft and provide critical but constructive feedback 
                on its clarity, strength of argument, writing style and engagement level. 
                Suggest specific improvements that could enhance the overall quality of the draft.
                Here is the draft:
                {draft}
                """ 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
# unittests.test_reflect_on_draft(reflect_on_draft)

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-5.2"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

# def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:
def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-5.2") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""Please revise the following blog post draft based on the reflection provided. 
                Incorporate the suggested improvements to enhance clarity, coherence, argumnet strength and overall flow.
                Here is the original draft:
                {original_draft}
                Here is the reflection:
                {reflection}
                """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
# unittests.test_revise_draft(revise_draft)

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

#  Specifying the models specifically and we can try OpenAI vs Claude vs Gemnini to see how the outputs differ.
# Agent 1 – Draft
draft = generate_draft(topic=essay_prompt, model="openai:gpt-5-nano")
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft=draft, model="openai:gpt-5.2")
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(original_draft=draft, reflection=feedback, model="openai:gpt-5.2")
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Introduction
# As social media increasingly shapes elections, markets, and everyday conversations, the idea of government regulation moves from the fringe to the mainstream. Advocates argue that oversight is needed to protect privacy, curb misinformation, and curb platform power. Critics warn it could chill speech and stifle innovation.
#
# Main Points
# - Protect users and privacy: enforce data minimization, consent, transparent data practices.
# - Stop manipulation: require transparency in ads, reveal algorithmic ranking criteria, and open data on content moderation guidelines.
# - Foster competition: prevent anti-competitive bundling, platform abuse, and give smaller players a fair shot with clear standards.
# - Guard against risks: avoid censorship and overreach; design regulation with independent, technocratic safeguards and sunset clauses.
#
# Conclusion
# A balanced approach is essential: baseline protections, flexible enforcement, and international cooperation to keep harms in check while preserving free expression and innovation.
#
# 🧠 Feedback:
#
# ## Clarity
#
# **What works**
# - The structure is easy to follow (intro → bullets → conclusion).
# - You present both sides briefly, which signals balance.
#
# **Where clarity can improve**
# - Several terms are broad or undefined: *“platform power,” “manipulation,” “algorithmic ranking criteria,” “technocratic safeguards.”* Readers may interpret these differently.
# - The bullets mix *goals* (protect privacy) with *mechanisms* (data minimization) and *institutions* (independent safeguards) without clearly separating them.
#
# **Specific improvements**
# - Add 1–2 sentences up front defining what “social media regulation” includes (privacy rules, ad transparency, competition policy, content governance) and what it *doesn’t* (e.g., direct government control of speech).
# - Turn each bullet into a mini-argument: **problem → proposed rule → expected benefit → key tradeoff**.
#
# ---
#
# ## Strength of argument
#
# **What works**
# - You identify four solid regulatory categories: privacy, transparency, competition, and civil liberties safeguards.
#
# **What weakens the argument**
# - The draft mostly lists assertions without evidence or examples. Without at least one concrete case per category, it reads like a policy outline rather than a persuasive blog post.
# - Some proposals are underspecified or potentially unrealistic as written. For example:
#   - “Reveal algorithmic ranking criteria” is ambiguous—full disclosure could enable gaming and expose trade secrets. More defensible: *risk assessments, independent audits, and user-facing explanations*.
#   - “Open data on content moderation guidelines” is good, but the stronger ask is *transparency reporting + appeals data + enforcement error rates*, not just publishing guidelines.
#
# **Specific improvements**
# - Add one example per point (short, not academic): e.g., targeted ad scandals, election misinformation spikes, app store bundling issues, or uneven moderation enforcement.
# - Include one paragraph that distinguishes between:
#   - **Speech regulation** (high risk)
#   - **Process and systems regulation** (lower risk): privacy, ad libraries, audits, accountability mechanisms
#   This helps neutralize the “censorship” critique with a clearer frame.
#
# ---
#
# ## Writing style
#
# **What works**
# - Clean, readable sentences.
# - Neutral tone—good for a contentious topic.
#
# **What to improve**
# - The bullets are somewhat “policy memo” style. A blog post needs more voice, specificity, and reader guidance.
# - Repetition: you use “curb” twice in the intro (“curb misinformation, and curb platform power”).
# - Parallelism: some bullets are nouns, others are verbs, others are mixed.
#
# **Specific improvements**
# - Use consistent bullet structure: start each with an action verb and keep them similar length.
# - Replace abstract phrases with concrete verbs:
#   - “stop manipulation” → “make influence campaigns traceable”
#   - “guard against risks” → “build guardrails against overreach”
# - Vary sentence rhythm; add a short punchy line after the opening to hook interest.
#
# ---
#
# ## Engagement level
#
# **What works**
# - Timely topic.
# - Balanced framing can attract a wider audience.
#
# **What’s missing**
# - A clear “so what” for the reader. Why should *they* care—what changes in their daily life?
# - No narrative hook, example, or tension beyond general claims.
#
# **Specific improvements**
# - Add a quick scenario in the intro (2–3 lines): what a user experiences—mysterious feed shifts, hyper-targeted political ads, data sharing surprises.
# - Add a brief “What this could look like in practice” section: 3–5 concrete regulatory tools (e.g., ad libraries, privacy default settings, audit requirements, interoperability) explained in plain language.
# - End with a sharper takeaway and a call to action (what should policymakers/platforms/users do next).
#
# ---
#
# ## Suggested rewrite approach (still your content, stronger delivery)
#
# ### 1) Stronger intro (example)
# Instead of staying abstract, you could open with a concrete hook:
# - *“If your feed suddenly fills with political content you never asked for, you’re seeing a system that can influence attention at scale—without much transparency.”*
# Then transition: regulation is moving mainstream because of privacy, misinformation, and concentrated market power.
#
# ### 2) Expand each bullet into a mini-paragraph (template)
# For each main point:
# - **Problem:** what’s going wrong?
# - **Policy:** what rule would address it?
# - **Safeguard:** how to prevent unintended harm?
# - **Metric:** how to know it’s working?
#
# Example for the algorithm point:
# - Problem: opaque ranking systems can amplify outrage.
# - Policy: require **independent audits** and **user-facing explanations**.
# - Safeguard: protect trade secrets; allow vetted auditors.
# - Metric: publish transparency reports on systemic risks and mitigation outcomes.
#
# ---
#
# ## Line-level edits you can apply immediately
#
# - Intro: change “curb misinformation, and curb platform power” → “limit misinformation and concentrated platform power.”
# - “Stop manipulation: require transparency in ads, reveal algorithmic ranking criteria…”
#   Consider: “Require political ad libraries, labeling for paid influence, and independent audits of ranking systems.”
# - “open data on content moderation guidelines” → “standardized transparency reports: rules, enforcement stats, appeals outcomes, and error rates.”
# - Conclusion: add specificity: what “baseline protections” are (privacy defaults, ad transparency) and what “flexible enforcement” means (risk-based tiers, sandbox pilots).
#
# ---
#
# ## One possible tightened outline (more blog-like)
#
# 1. **Why regulation is back on the table** (1 short story + 2 stakes)
# 2. **What we should regulate (and what we shouldn’t)** (process vs speech)
# 3. **Four pillars**
#    - Privacy and data limits
#    - Traceable advertising and influence
#    - Accountability for algorithms (audits, explanations)
#    - Competition and interoperability
# 4. **Guardrails against censorship and capture** (independent oversight, due process, sunset clauses)
# 5. **What success looks like** (2–3 measurable outcomes)
#
# ---
#
# If you tell me your intended audience (general readers vs policy professionals), your desired length, and whether you want a pro-regulation or “balanced but skeptical” stance, I can propose a revised draft in your voice.
#
# ✍️ Revised:
#
# ## Regulating Social Media Without Regulating Speech
#
# ### Introduction
# If your feed suddenly fills with political posts you never asked for—or an ad seems to know a little too much about your personal life—you’re experiencing how social platforms can shape attention and behavior at scale, often with limited transparency.
#
# That’s why “social media regulation” is moving from a fringe idea to a mainstream debate. In practice, regulation can mean **privacy rules**, **ad transparency**, **competition policy**, and **accountability requirements for platform systems** (like ranking and recommendation). What it *shouldn’t* mean is the government directly deciding which opinions are allowed online. The challenge is building rules that reduce real harms—without turning platforms into state-managed speech systems.
#
# ---
#
# ## What we should regulate (and what we shouldn’t)
# A useful distinction is:
#
# - **Speech regulation (high risk):** laws that directly restrict or mandate specific viewpoints. These can easily become censorship tools, especially when political power changes hands.
# - **Process and systems regulation (lower risk):** rules about *how* platforms collect data, run ads, rank content, and enforce their own policies—focused on transparency, user rights, and accountability rather than policing ideas.
#
# Most of the strongest proposals fall into the second category: regulating systems and incentives, not opinions.
#
# ---
#
# ## Four pillars of a smarter approach
#
# ### 1) Strengthen privacy and limit data collection
# **Problem:** Many platforms rely on extensive tracking and data brokerage to fuel hyper-targeted advertising. Users often don’t realize how widely their data travels—or how hard it is to meaningfully opt out. The result can be anything from creepy personalization to major exposure when data is mishandled. (If you’ve ever searched for something once and seen it “follow you” everywhere, you’ve felt the logic of this system.)
#
# **Proposed rules:** Require **data minimization** (collect only what’s needed), **clear consent** (no dark patterns), and **plain-language disclosure** about what data is collected, shared, and retained.
#
# **Expected benefit:** Less surveillance by default, fewer large-scale leaks, and reduced incentive to monetize the most sensitive parts of people’s lives.
#
# **Tradeoff to manage:** Overly rigid rules can burden small companies. A workable approach sets baseline protections for everyone, with scaled compliance requirements based on size and risk.
#
# **How to know it’s working:** Fewer third-party data transfers, lower breach impact, and measurable reductions in targeted advertising based on sensitive categories.
#
# ---
#
# ### 2) Make influence campaigns traceable (especially paid ones)
# **Problem:** Political and issue-based messaging can be microtargeted, duplicated, and optimized faster than the public can scrutinize it. During elections or major crises, “who is trying to persuade me—and why?” often becomes impossible to answer.
#
# **Proposed rules:** Require **public ad libraries** for political and major-issue ads, clear **labels for paid influence**, and disclosure of key information such as the sponsor, targeting criteria (at least at a high level), and total spend.
#
# **Expected benefit:** Journalists, researchers, and the public can spot coordinated influence campaigns earlier—and platforms can’t quietly profit from opaque political targeting.
#
# **Tradeoff to manage:** Transparency must not become a how-to manual for manipulation. Reporting can be delayed slightly for safety, and targeting disclosures can be aggregated to avoid exposing sensitive individual-level details.
#
# **How to know it’s working:** Faster detection of coordinated campaigns, clearer attribution of sponsors, and fewer “unknown source” viral ad operations.
#
# ---
#
# ### 3) Increase accountability for algorithms—without forcing companies to publish trade secrets
# **Problem:** Ranking and recommendation systems can amplify outrage, misinformation, or extreme content because it drives engagement. Users see outcomes (their feed), but not the logic shaping it. When the system causes harm, platforms can claim it’s too complex to explain.
#
# **Proposed rules:** Instead of “revealing the algorithm,” require **independent audits**, **risk assessments**, and **user-facing explanations** (e.g., “why am I seeing this?” with meaningful factors). Add requirements for standardized **transparency reporting** on systemic risks and mitigation efforts.
#
# **Expected benefit:** Platforms remain free to innovate, but must demonstrate they have tested and managed predictable harms—similar to safety expectations in other industries.
#
# **Tradeoff to manage:** Audits must protect trade secrets and security. The solution is vetted third-party auditors, secure data rooms, and clear standards for what must be reported publicly versus confidentially.
#
# **How to know it’s working:** Published audit outcomes and risk reports, measurable reductions in repeat amplification of known harmful content patterns, and clearer user controls over recommendation settings.
#
# ---
#
# ### 4) Promote real competition so users have meaningful choices
# **Problem:** When a few platforms dominate, users and creators can’t easily leave—because their audiences, contacts, and work are trapped. Dominant platforms can also bundle services, copy competitors, or set rules that smaller players can’t survive.
#
# **Proposed rules:** Enforce competition policy against anti-competitive conduct and require **interoperability and portability** where appropriate—so people can move their data, connections, and content more easily (without starting from zero).
#
# **Expected benefit:** Platforms have to compete on trust, features, and user experience—not just on lock-in. Smaller services get a fairer shot, and innovation is less dependent on gatekeepers.
#
# **Tradeoff to manage:** Interoperability can raise security and privacy risks if done carelessly. Standards should be phased, scoped, and tested—especially for messaging, identity, and data transfer.
#
# **How to know it’s working:** Lower switching costs, more viable competitors, and reduced dependence on a single platform for reaching an audience.
#
# ---
#
# ## Guardrails against overreach and capture
# Even well-intended regulation can go wrong if it becomes a tool for censorship or a set of rules written by incumbents to block competitors. Three design choices help:
#
# - **Independent oversight and due process:** clear rules, appeal rights, and documented enforcement—so moderation isn’t arbitrary and governments aren’t quietly pressuring platforms.
# - **Technically competent enforcement:** regulators who can evaluate audits, security, and ad systems—without dictating political outcomes.
# - **Sunset clauses and periodic review:** because the internet changes quickly, rules should be revisited and adjusted based on evidence.
#
# ---
#
# ## What this could look like in practice (plain-language tools)
# A realistic regulatory package doesn’t need to be huge to matter. It could include:
#
# 1) **Privacy-by-default settings** and limits on sensitive data targeting
# 2) **Political/issue ad libraries** with sponsor identity and spend transparency
# 3) **Independent algorithmic audits** and public risk reporting (with protected trade secrets)
# 4) **Standardized transparency reports**: rules, enforcement stats, appeals outcomes, and error rates
# 5) **Portability/interoperability requirements** that let users leave without losing everything
#
# ---
#
# ## Conclusion
# A workable middle path is possible: regulate **systems** (data, ads, accountability, competition) rather than **opinions**. Done well, social media regulation can mean fewer privacy surprises, fewer opaque influence campaigns, and more real choice—without handing governments a direct lever over speech.
#
# The next step is practical: policymakers should focus on enforceable, measurable rules; platforms should accept independent accountability as the cost of operating at societal scale; and users should demand defaults that protect them without requiring a law degree to understand the settings.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Introduction
# As social media increasingly shapes elections, markets, and everyday conversations, the idea of government regulation moves from the fringe to the mainstream. Advocates argue that oversight is needed to protect privacy, curb misinformation, and curb platform power. Critics warn it could chill speech and stifle innovation.
#
# Main Points
# - Protect users and privacy: enforce data minimization, consent, transparent data practices.
# - Stop manipulation: require transparency in ads, reveal algorithmic ranking criteria, and open data on content moderation guidelines.
# - Foster competition: prevent anti-competitive bundling, platform abuse, and give smaller players a fair shot with clear standards.
# - Guard against risks: avoid censorship and overreach; design regulation with independent, technocratic safeguards and sunset clauses.
#
# Conclusion
# A balanced approach is essential: baseline protections, flexible enforcement, and international cooperation to keep harms in check while preserving free expression and innovation.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">## Clarity
#
# **What works**
# - The structure is easy to follow (intro → bullets → conclusion).
# - You present both sides briefly, which signals balance.
#
# **Where clarity can improve**
# - Several terms are broad or undefined: *“platform power,” “manipulation,” “algorithmic ranking criteria,” “technocratic safeguards.”* Readers may interpret these differently.
# - The bullets mix *goals* (protect privacy) with *mechanisms* (data minimization) and *institutions* (independent safeguards) without clearly separating them.
#
# **Specific improvements**
# - Add 1–2 sentences up front defining what “social media regulation” includes (privacy rules, ad transparency, competition policy, content governance) and what it *doesn’t* (e.g., direct government control of speech).
# - Turn each bullet into a mini-argument: **problem → proposed rule → expected benefit → key tradeoff**.
#
# ---
#
# ## Strength of argument
#
# **What works**
# - You identify four solid regulatory categories: privacy, transparency, competition, and civil liberties safeguards.
#
# **What weakens the argument**
# - The draft mostly lists assertions without evidence or examples. Without at least one concrete case per category, it reads like a policy outline rather than a persuasive blog post.
# - Some proposals are underspecified or potentially unrealistic as written. For example:
#   - “Reveal algorithmic ranking criteria” is ambiguous—full disclosure could enable gaming and expose trade secrets. More defensible: *risk assessments, independent audits, and user-facing explanations*.
#   - “Open data on content moderation guidelines” is good, but the stronger ask is *transparency reporting + appeals data + enforcement error rates*, not just publishing guidelines.
#
# **Specific improvements**
# - Add one example per point (short, not academic): e.g., targeted ad scandals, election misinformation spikes, app store bundling issues, or uneven moderation enforcement.
# - Include one paragraph that distinguishes between:
#   - **Speech regulation** (high risk)
#   - **Process and systems regulation** (lower risk): privacy, ad libraries, audits, accountability mechanisms
#   This helps neutralize the “censorship” critique with a clearer frame.
#
# ---
#
# ## Writing style
#
# **What works**
# - Clean, readable sentences.
# - Neutral tone—good for a contentious topic.
#
# **What to improve**
# - The bullets are somewhat “policy memo” style. A blog post needs more voice, specificity, and reader guidance.
# - Repetition: you use “curb” twice in the intro (“curb misinformation, and curb platform power”).
# - Parallelism: some bullets are nouns, others are verbs, others are mixed.
#
# **Specific improvements**
# - Use consistent bullet structure: start each with an action verb and keep them similar length.
# - Replace abstract phrases with concrete verbs:
#   - “stop manipulation” → “make influence campaigns traceable”
#   - “guard against risks” → “build guardrails against overreach”
# - Vary sentence rhythm; add a short punchy line after the opening to hook interest.
#
# ---
#
# ## Engagement level
#
# **What works**
# - Timely topic.
# - Balanced framing can attract a wider audience.
#
# **What’s missing**
# - A clear “so what” for the reader. Why should *they* care—what changes in their daily life?
# - No narrative hook, example, or tension beyond general claims.
#
# **Specific improvements**
# - Add a quick scenario in the intro (2–3 lines): what a user experiences—mysterious feed shifts, hyper-targeted political ads, data sharing surprises.
# - Add a brief “What this could look like in practice” section: 3–5 concrete regulatory tools (e.g., ad libraries, privacy default settings, audit requirements, interoperability) explained in plain language.
# - End with a sharper takeaway and a call to action (what should policymakers/platforms/users do next).
#
# ---
#
# ## Suggested rewrite approach (still your content, stronger delivery)
#
# ### 1) Stronger intro (example)
# Instead of staying abstract, you could open with a concrete hook:
# - *“If your feed suddenly fills with political content you never asked for, you’re seeing a system that can influence attention at scale—without much transparency.”*
# Then transition: regulation is moving mainstream because of privacy, misinformation, and concentrated market power.
#
# ### 2) Expand each bullet into a mini-paragraph (template)
# For each main point:
# - **Problem:** what’s going wrong?
# - **Policy:** what rule would address it?
# - **Safeguard:** how to prevent unintended harm?
# - **Metric:** how to know it’s working?
#
# Example for the algorithm point:
# - Problem: opaque ranking systems can amplify outrage.
# - Policy: require **independent audits** and **user-facing explanations**.
# - Safeguard: protect trade secrets; allow vetted auditors.
# - Metric: publish transparency reports on systemic risks and mitigation outcomes.
#
# ---
#
# ## Line-level edits you can apply immediately
#
# - Intro: change “curb misinformation, and curb platform power” → “limit misinformation and concentrated platform power.”
# - “Stop manipulation: require transparency in ads, reveal algorithmic ranking criteria…”
#   Consider: “Require political ad libraries, labeling for paid influence, and independent audits of ranking systems.”
# - “open data on content moderation guidelines” → “standardized transparency reports: rules, enforcement stats, appeals outcomes, and error rates.”
# - Conclusion: add specificity: what “baseline protections” are (privacy defaults, ad transparency) and what “flexible enforcement” means (risk-based tiers, sandbox pilots).
#
# ---
#
# ## One possible tightened outline (more blog-like)
#
# 1. **Why regulation is back on the table** (1 short story + 2 stakes)
# 2. **What we should regulate (and what we shouldn’t)** (process vs speech)
# 3. **Four pillars**
#    - Privacy and data limits
#    - Traceable advertising and influence
#    - Accountability for algorithms (audits, explanations)
#    - Competition and interoperability
# 4. **Guardrails against censorship and capture** (independent oversight, due process, sunset clauses)
# 5. **What success looks like** (2–3 measurable outcomes)
#
# ---
#
# If you tell me your intended audience (general readers vs policy professionals), your desired length, and whether you want a pro-regulation or “balanced but skeptical” stance, I can propose a revised draft in your voice.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">## Regulating Social Media Without Regulating Speech
#
# ### Introduction
# If your feed suddenly fills with political posts you never asked for—or an ad seems to know a little too much about your personal life—you’re experiencing how social platforms can shape attention and behavior at scale, often with limited transparency.
#
# That’s why “social media regulation” is moving from a fringe idea to a mainstream debate. In practice, regulation can mean **privacy rules**, **ad transparency**, **competition policy**, and **accountability requirements for platform systems** (like ranking and recommendation). What it *shouldn’t* mean is the government directly deciding which opinions are allowed online. The challenge is building rules that reduce real harms—without turning platforms into state-managed speech systems.
#
# ---
#
# ## What we should regulate (and what we shouldn’t)
# A useful distinction is:
#
# - **Speech regulation (high risk):** laws that directly restrict or mandate specific viewpoints. These can easily become censorship tools, especially when political power changes hands.
# - **Process and systems regulation (lower risk):** rules about *how* platforms collect data, run ads, rank content, and enforce their own policies—focused on transparency, user rights, and accountability rather than policing ideas.
#
# Most of the strongest proposals fall into the second category: regulating systems and incentives, not opinions.
#
# ---
#
# ## Four pillars of a smarter approach
#
# ### 1) Strengthen privacy and limit data collection
# **Problem:** Many platforms rely on extensive tracking and data brokerage to fuel hyper-targeted advertising. Users often don’t realize how widely their data travels—or how hard it is to meaningfully opt out. The result can be anything from creepy personalization to major exposure when data is mishandled. (If you’ve ever searched for something once and seen it “follow you” everywhere, you’ve felt the logic of this system.)
#
# **Proposed rules:** Require **data minimization** (collect only what’s needed), **clear consent** (no dark patterns), and **plain-language disclosure** about what data is collected, shared, and retained.
#
# **Expected benefit:** Less surveillance by default, fewer large-scale leaks, and reduced incentive to monetize the most sensitive parts of people’s lives.
#
# **Tradeoff to manage:** Overly rigid rules can burden small companies. A workable approach sets baseline protections for everyone, with scaled compliance requirements based on size and risk.
#
# **How to know it’s working:** Fewer third-party data transfers, lower breach impact, and measurable reductions in targeted advertising based on sensitive categories.
#
# ---
#
# ### 2) Make influence campaigns traceable (especially paid ones)
# **Problem:** Political and issue-based messaging can be microtargeted, duplicated, and optimized faster than the public can scrutinize it. During elections or major crises, “who is trying to persuade me—and why?” often becomes impossible to answer.
#
# **Proposed rules:** Require **public ad libraries** for political and major-issue ads, clear **labels for paid influence**, and disclosure of key information such as the sponsor, targeting criteria (at least at a high level), and total spend.
#
# **Expected benefit:** Journalists, researchers, and the public can spot coordinated influence campaigns earlier—and platforms can’t quietly profit from opaque political targeting.
#
# **Tradeoff to manage:** Transparency must not become a how-to manual for manipulation. Reporting can be delayed slightly for safety, and targeting disclosures can be aggregated to avoid exposing sensitive individual-level details.
#
# **How to know it’s working:** Faster detection of coordinated campaigns, clearer attribution of sponsors, and fewer “unknown source” viral ad operations.
#
# ---
#
# ### 3) Increase accountability for algorithms—without forcing companies to publish trade secrets
# **Problem:** Ranking and recommendation systems can amplify outrage, misinformation, or extreme content because it drives engagement. Users see outcomes (their feed), but not the logic shaping it. When the system causes harm, platforms can claim it’s too complex to explain.
#
# **Proposed rules:** Instead of “revealing the algorithm,” require **independent audits**, **risk assessments**, and **user-facing explanations** (e.g., “why am I seeing this?” with meaningful factors). Add requirements for standardized **transparency reporting** on systemic risks and mitigation efforts.
#
# **Expected benefit:** Platforms remain free to innovate, but must demonstrate they have tested and managed predictable harms—similar to safety expectations in other industries.
#
# **Tradeoff to manage:** Audits must protect trade secrets and security. The solution is vetted third-party auditors, secure data rooms, and clear standards for what must be reported publicly versus confidentially.
#
# **How to know it’s working:** Published audit outcomes and risk reports, measurable reductions in repeat amplification of known harmful content patterns, and clearer user controls over recommendation settings.
#
# ---
#
# ### 4) Promote real competition so users have meaningful choices
# **Problem:** When a few platforms dominate, users and creators can’t easily leave—because their audiences, contacts, and work are trapped. Dominant platforms can also bundle services, copy competitors, or set rules that smaller players can’t survive.
#
# **Proposed rules:** Enforce competition policy against anti-competitive conduct and require **interoperability and portability** where appropriate—so people can move their data, connections, and content more easily (without starting from zero).
#
# **Expected benefit:** Platforms have to compete on trust, features, and user experience—not just on lock-in. Smaller services get a fairer shot, and innovation is less dependent on gatekeepers.
#
# **Tradeoff to manage:** Interoperability can raise security and privacy risks if done carelessly. Standards should be phased, scoped, and tested—especially for messaging, identity, and data transfer.
#
# **How to know it’s working:** Lower switching costs, more viable competitors, and reduced dependence on a single platform for reaching an audience.
#
# ---
#
# ## Guardrails against overreach and capture
# Even well-intended regulation can go wrong if it becomes a tool for censorship or a set of rules written by incumbents to block competitors. Three design choices help:
#
# - **Independent oversight and due process:** clear rules, appeal rights, and documented enforcement—so moderation isn’t arbitrary and governments aren’t quietly pressuring platforms.
# - **Technically competent enforcement:** regulators who can evaluate audits, security, and ad systems—without dictating political outcomes.
# - **Sunset clauses and periodic review:** because the internet changes quickly, rules should be revisited and adjusted based on evidence.
#
# ---
#
# ## What this could look like in practice (plain-language tools)
# A realistic regulatory package doesn’t need to be huge to matter. It could include:
#
# 1) **Privacy-by-default settings** and limits on sensitive data targeting
# 2) **Political/issue ad libraries** with sponsor identity and spend transparency
# 3) **Independent algorithmic audits** and public risk reporting (with protected trade secrets)
# 4) **Standardized transparency reports**: rules, enforcement stats, appeals outcomes, and error rates
# 5) **Portability/interoperability requirements** that let users leave without losing everything
#
# ---
#
# ## Conclusion
# A workable middle path is possible: regulate **systems** (data, ads, acco

# %% [markdown]
# ## Check grading feedback
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading.
